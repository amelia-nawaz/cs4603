# %%
# %run ../shared_notebook_setup.py

# %%
messages=[
    {
      "role": "user",
      "content": "How are you?",
    }
  ]

chat_completion = client.chat.completions.create(
  messages=messages,
  model=DATABRICKS_MODEL
)

# %%
pprint(chat_completion.choices[0].message.content)
# Out:
# [
#     {
#         'summary': [
#             {
#                 'text': 'Thinking Process:\n\n1.  **Analyze the Request:**\n    *   Input: "How are you?"\n    *   Intent: Greeting/Small talk.\n    *   Expected Output: A polite, friendly response indicating my status as an AI and offering assistance.\n\n2.  **Determine the appropriate tone:**\n    *   Friendly, helpful, concise.\n    *   Acknowledge my nature (AI) without being overly robotic.\n\n3.  **Draft potential responses:**\n    *   *Option 1:* I\'m fine, thanks. How about you? (A bit generic)\n    *   *Option 2:* I\'m doing well! As an AI, I don\'t have feelings, but I\'m ready to help. (Accurate but slightly dry)\n    *   *Option 3:* I\'m doing great, thank you for asking! How are you doing today? Anything I can help you with? (Friendly and service-oriented)\n\n4.  **Select the best option:** Option 3 is balanced. It\'s polite, friendly, and opens the floor for further interaction.\n\n5.  **Refine the response:** "I\'m doing well, thank you! How about you? Is there anything I can help you with today?"\n\n6.  **Final Polish:** Keep it natural. "I\'m doing well, thanks for asking! How about you? Anything interesting going on, or is there something I can help you with?"\n\n7.  **Final Decision:** "I\'m doing well, thanks! How about you? Is there anything I can help you with today?" (Simple and effective).\n\n8.  **Output Generation:** (Matches the selected decision)cw',
#                 'type': 'summary_text',
#             },
#         ],
#         'type': 'reasoning',
#     },
#     {
#         'text': "I'm doing well, thanks for asking! How about you? Is there anything I can help you with today?",
#         'type': 'text',
#     },
# ]

# %%
def print_token_usage(chat_completion):
    pprint(f"Model used: {chat_completion.model}")
    pprint(f"Input tokens: {chat_completion.usage.prompt_tokens}")
    pprint(f"Output tokens: {chat_completion.usage.completion_tokens}")
    pprint(f"Total tokens: {chat_completion.usage.total_tokens}")

# %%
print_token_usage(chat_completion)
# Out:
# 'Model used: qwen35-122b-a10b'
# 'Input tokens: 14'
# 'Output tokens: 385'
# 'Total tokens: 399'

# %%
DATABRICKS_ENDPOINT = "databricks-meta-llama-3-3-70b-instruct"

chat_completion = client.chat.completions.create(
    messages=messages,
    model=DATABRICKS_ENDPOINT
)

print(chat_completion.choices[0].message.content)
print_token_usage(chat_completion)
# Out:
# I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to assist you with any questions or tasks you may have. How can I help you today?
# 'Model used: meta-llama-3.3-70b-instruct-121024'
# 'Input tokens: 39'
# 'Output tokens: 46'
# 'Total tokens: 85'
